# %% [markdown]
# # Assignment 3: Clustering
#
# Density-based, hierarchical, and prototype-based clustering across Breast Cancer Wisconsin, Iris, and Wine datasets. Generates metric tables, plots, and report.pdf.

# %% [markdown]
# Run the next cell to execute the complete implementation. It uses `/usr/bin/python3` because the default `python3` on this machine points to a separate runtime without the required data-science packages.

# %%
from pathlib import Path
import subprocess

ASSIGNMENT_DIR = Path.cwd()
if not (ASSIGNMENT_DIR / "assignment3_clustering.py").exists():
    ASSIGNMENT_DIR = Path(r"/mnt/TBT_DATA/nipun/work/data_mining/Assignment3")

subprocess.run([r"/usr/bin/python3", str(ASSIGNMENT_DIR / "assignment3_clustering.py")], check=True)

# %% [markdown]
# ## Result Summary

# %%
import json
import pandas as pd
from pathlib import Path

base = ASSIGNMENT_DIR
with open(base / "results" / "assignment3_results.json") as fh:
    results = json.load(fh)
print("Best density results:")
display(pd.DataFrame(results["best_density"]))
print("Best hierarchical results:")
display(pd.DataFrame(results["best_hierarchical"]))
print("Best prototype results:")
display(pd.DataFrame(results["best_prototype"]))
